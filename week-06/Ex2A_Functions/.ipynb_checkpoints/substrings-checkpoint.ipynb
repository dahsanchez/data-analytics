# %% [markdown]
# # Exercise 2.A Using built-in functions

# %% [markdown]
# ## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
 for i in range(len(name)):
     if name[i] == ' ':
         first = name[:i]
         last = name[i+1:]
         print(f"Full name: {name}")
         print(f"First name: {first}")
         print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0]) # output for Grace Flores
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores

# %%
my_name = 'Dahlia Sanchez'

# %%
parse_and_display(my_name)
# Out:
# Full name: Dahlia Sanchez
# First name: Dahlia
# Last name: Sanchez

# %%
parse_and_display('Dahlia Sanchez')
# Out:
# Full name: Dahlia Sanchez
# First name: Dahlia
# Last name: Sanchez
