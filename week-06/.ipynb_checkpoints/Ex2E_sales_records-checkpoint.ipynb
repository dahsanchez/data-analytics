# %% [markdown]
# # Sales Records Analysis

# %% [markdown]
# ### Author: Dahlia Sanchez

# %% [markdown]
# ### Exercise 2.E Using functions for analyzing data

# %% [markdown]
# This notebook analyzes a small sales dataset using Python functions.Each function takes the full dataset as its first argument.

# %%
sales_data = [
 ('Laptop', 'East', 1200.00),
 ('Phone', 'West', 850.00),
 ('Tablet', 'East', 400.00),
 ('Monitor', 'South', 650.00),
 ('Keyboard', 'West', 75.00),
 ('Laptop', 'South', 1150.00),
 ('Phone', 'East', 900.00),
('Tablet', 'West', 425.00),
 ('Monitor', 'East', 680.00),
 ('Keyboard', 'South', 80.00),
 ('Laptop', 'West', 1300.00),
 ('Phone', 'West', 820.00),
]

# %% [markdown]
# ## Lab 1. Total sales by region

# %%
def region_total(data, region):
 return sum(amt for _, r, amt in data if r == region)

# %%
print(region_total(sales_data, 'East'))
print(region_total(sales_data, 'West'))
print(region_total(sales_data, 'South'))
# Out:
# 3180.0
# 3470.0
# 1880.0

# %% [markdown]
# ## Lab 2. Count of sales by region

# %%
def region_count(data, region):
    return sum(1 for _, r, amt in data if r == region)

# %%
print(region_count(sales_data, 'East'))
print(region_count(sales_data, 'West'))
print(region_count(sales_data, 'South'))
# Out:
# 4
# 5
# 3

# %% [markdown]
# ## Lab 3. Average sale amount by region

# %%
def region_average(data, region):
    count = region_count(data, region)
    if count == 0:
        return 0
    total = region_total(data, region)
    return total / count

# %%
print(region_average(sales_data, 'East'))
print(region_average(sales_data, 'West'))
print(region_average(sales_data, 'South'))
print(region_average(sales_data, 'North'))
# Out:
# 795.0
# 694.0
# 626.6666666666666
# 0

# %% [markdown]
# ## Lab 4. Filter by sale amount

# %%
def sales_above(data, threshold):
    return  [sale for sale in data if sale[2] > threshold]

# %%
sale_amount = sales_above(sales_data,500)
for sale_amount in sale_amount:
    print(sale_amount)
# Out:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Monitor', 'South', 650.0)
# ('Laptop', 'South', 1150.0)
# ('Phone', 'East', 900.0)
# ('Monitor', 'East', 680.0)
# ('Laptop', 'West', 1300.0)
# ('Phone', 'West', 820.0)

# %% [markdown]
# ## Lab 5. Top and bottom sale

# %%
def top_sale(data):
    return max(data, key = lambda s: s[2])

# %%
def bottom_sale(data):
    return min(data, key = lambda s: s[2])

# %%
print(top_sale(sales_data))
print(bottom_sale(sales_data))
# Out:
# ('Laptop', 'West', 1300.0)
# ('Keyboard', 'West', 75.0)

# %% [markdown]
# The top sale was a laptop in the West region for $1300.

# %% [markdown]
# The lowest sale was a keyboard in the West region for $75.

# %% [markdown]
# ## Lab 6. Apply a discount

# %%
def apply_discount(data, discount_pct):
    return list (
        map(
            lambda s: (s[0], s[1], s[2] * (1 - discount_pct)),
            data
        )
    )

# %%
discount = apply_discount(sales_data,0.15)

print('Before discount: ')
for sale in sales_data[:3]:
    print(sale)

print('\nAfter a 15% discount: ')
for sale in discount[:3]:
    print(sale)
# Out:
# Before discount:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Tablet', 'East', 400.0)
#
# After a 15% discount:
# ('Laptop', 'East', 1020.0)
# ('Phone', 'West', 722.5)
# ('Tablet', 'East', 340.0)

# %% [markdown]
# ## Lab 7. Unique regions

# %%
def unique_regions(data):
    return sorted(set(region for _, region, _ in data))

# %%
print(unique_regions(sales_data))
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# This function can help when using large data sets to quickly show all the unique types in a data set without having to manually seach for them.

# %% [markdown]
# ## Lab 8. Region summary

# %%
def region_summary(data, region):
    region_data = [s for s in data if s[1] == region]

    total = region_total(data, region)
    count = region_count(data, region)
    average = region_average(data, region)
    top = max(region_data, key=lambda s: s[2])

    print(f'''=== {region} Region ===
    Records: {count}
    Total Sales: ${total:,.2f}
    Average Sale: ${average:,.2f}
    Top Sale: {top[0]}: ${top[2]:,.2f}''')
    return ' '

# %%
print(region_summary(sales_data,'West'))
# Out:
# === West Region ===
#     Records: 5
#     Total Sales: $3,470.00
#     Average Sale: $694.00
#     Top Sale: Laptop: $1,300.00

# %% [markdown]
# ## Lab 9. Full summary

# %%
for region in unique_regions(sales_data):
    region_summary(sales_data,region)
    print()
# Out:
# === East Region ===
#     Records: 4
#     Total Sales: $3,180.00
#     Average Sale: $795.00
#     Top Sale: Laptop: $1,200.00
#
# === South Region ===
#     Records: 3
#     Total Sales: $1,880.00
#     Average Sale: $626.67
#     Top Sale: Laptop: $1,150.00
#
# === West Region ===
#     Records: 5
#     Total Sales: $3,470.00
#     Average Sale: $694.00
#     Top Sale: Laptop: $1,300.00

# %% [markdown]
# ### Summary

# %% [markdown]
# In these labs, I learned how to build and apply Python functions to analyze data effectively. I practiced working with loops, lists, generator expressions, lambda functions, map(), filtering techniques, and calculating totals and averages. I also developed skills in organizing and summarizing data clearly by creating reusable functions.
