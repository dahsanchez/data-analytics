# %% [markdown]
# # Lab 1 of Exercise 2.C

# %% [markdown]
# ## working with defining custom functions

# %% [markdown]
# ## Favorite things

# %%
def favorite_things(name,movie,music):
  return(f' My name is {name}. My favorite movie is {movie}. My favorite band is {music}.')

# %%
print(favorite_things('Dahlia','The Sandlot','BTS'))
# Out:
#  My name is Dahlia. My favorite movie is The Sandlot. My favorite band is BTS.

# %% [markdown]
# ## Why im here

# %%
def why_im_here(purpose):
    return purpose

# %%
print(why_im_here('I joined the Year Up United Data Analytics program because i wanted to have a foot in the door to the tech world'))
# Out:
#  I joined the Year Up United Data Analytics program because i wanted to have a foot in the door to the tech world

# %% [markdown]
# ## Favorite place

# %%
def  favorite_place(place,why):
    return (f'One of my favorite places is {place} because {why}')

# %%
print(favorite_place('Japanese Gardens','its a place i go when i want to relax and think'))
# Out:
# One of my favorite places is Japanese Gardens because its a place i go when i want to relax and think

# %%
print(favorite_place('the aquarium','i love to learn about the ocean and its another place i like to relax'))
# Out:
# One of my favorite places is the aquarium because i love to learn about the ocean and its another place i like to relax
